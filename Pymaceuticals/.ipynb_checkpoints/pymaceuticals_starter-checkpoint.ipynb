# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# %matplotlib inline

# %%
### How do upload to github? I created a repository. How does it know to upload this project to the correct repository?

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combined_data_df = pd.merge(mouse_metadata, study_results,
                                 how='outer', on="Mouse ID")
# Display the data table for preview

combined_data_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
print(f"Number of Mice: {len(combined_data_df)}")
# Out:
# Number of Mice: 1893

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicates = combined_data_df[combined_data_df.duplicated(['Mouse ID', 'Timepoint'], keep="first")]

duplicates.head(100)
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicates = combined_data_df[combined_data_df.duplicated(['Mouse ID', 'Timepoint', 'Drug Regimen'], keep="last")]

duplicates.head(100)
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 910           48.786801                 0
# 912           51.745156                 0
# 914           51.325852                 1
# 916           55.326122                 1

# %%
###duplicate_mouse_ids = study_data_complete.loc[study_data_complete.duplicated(subset=['Mouse ID', 'Timepoint']),'Mouse ID'].unique()
###duplicate_mouse_ids

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = combined_data_df.drop_duplicates(subset=["Mouse ID", "Timepoint"], keep='last')
clean_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice in the clean DataFrame.
print(f"Number of Mice: {len(clean_df)}")
# Out:
# Number of Mice: 1888

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

drug_grouped = clean_df.groupby(["Drug Regimen"])

mean = drug_grouped["Tumor Volume (mm3)"].mean()

median = drug_grouped["Tumor Volume (mm3)"].median()

variance = drug_grouped["Tumor Volume (mm3)"].var()

std = drug_grouped["Tumor Volume (mm3)"].std()

sem = drug_grouped["Tumor Volume (mm3)"].sem()

summary_statistics = pd.DataFrame({"Mean": mean, "Median": median, "Variance": variance, "Standard Deviation": std, "SEM": sem})

summary_statistics.head(5)
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466

# %%
mean_agg = clean_df["Tumor Volume (mm3)"].mean()
median_agg = clean_df["Tumor Volume (mm3)"].median()
variance_agg = clean_df["Tumor Volume (mm3)"].var()
std_agg = clean_df["Tumor Volume (mm3)"].std()
sem_agg = clean_df["Tumor Volume (mm3)"].sem()

print(f"Mean: {round(mean_agg, 2)}; Median: {round(median_agg, 2)}; Variance: {round(variance_agg, 2)}; Standard Deviation: {round(std_agg, 2)}; SEM: {round(sem_agg, 2)}")
        
summary = clean_df["Tumor Volume (mm3)"].agg(["count", "mean","median", "var", "std", "sem"])

summary
# Out:
# Mean: 50.45; Median: 48.95; Variance: 79.29; Standard Deviation: 8.9; SEM: 0.2
# count     1888.000000
# mean        50.448411
# median      48.951421
# var         79.294606
# std          8.904752
# sem          0.204937
# Name: Tumor Volume (mm3), dtype: float64

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pandas.


summary_unique_mice = clean_df.loc[:,["Drug Regimen", "Mouse ID"]]

summary_chart = summary_unique_mice.groupby(["Drug Regimen", "Mouse ID"])

mice = summary_unique_mice.groupby(["Drug Regimen"]).nunique()

summary_df = pd.DataFrame(mice)

New = summary_df.rename(columns={"Mouse ID": "Number of Mice"})

New

summary_df.plot.bar()
# Out:
# <AxesSubplot:xlabel='Drug Regimen'>

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pyplot.

count_chart = New.plot(kind='bar')

count_chart.set_xlabel("Drug Regimen")
count_chart.set_ylabel("Number of Mice")


plt.show()
plt.tight_layout()

# %%
###How do I refer to a list instead of creating a list?


# Generate a pie plot showing the distribution of female versus male mice using pandas

summary_mice_sex = clean_df.loc[:,["Sex", "Mouse ID"]]

mice = summary_mice_sex.groupby(["Sex"]).nunique()

summary_df = pd.DataFrame(mice)

mice_list = summary_df["Mouse ID"].tolist()





df = pd.DataFrame({'Sex': mice_list},

                  index=["Female", "Male"])

plot = df.plot.pie(y='Sex', autopct='%1.1f%%', figsize=(5, 5))

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

summary_mice_sex = clean_df.loc[:,["Sex", "Mouse ID"]]

mice = summary_mice_sex.groupby(["Sex"]).nunique()

summary_df = pd.DataFrame(mice)

#labels = ["Male", "Female"]

mice_list = summary_df["Mouse ID"].tolist()


# The values of each section of the pie chart
counts = summary_df.value_counts("Mouse ID")

plt.pie(mice_list, labels=labels, shadow=True, autopct= "%1.1f%%", startangle=140)

mice_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-278e67abfa09> in <module>
#      15 counts = summary_df.value_counts("Mouse ID")
#      16
# ---> 17 plt.pie(mice_list, labels=labels, shadow=True, autopct= "%1.1f%%", startangle=140)
#      18
#      19 mice_list
#
# NameError: name 'labels' is not defined

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse

#summary_tumor = tumor_volume.groupby["Drug Regimen"]

clean_df = clean_df[clean_df['Drug Regimen'].str.contains("Capomulin|Ramicane|Infubinol|Ceftamin")]

grouped = clean_df.groupby(["Drug Regimen", "Mouse ID"])
filter_tumor_max = grouped.max("Timepoint")
filter_tumor_max_df = pd.DataFrame(filter_tumor_max)

filter_tumor_max_df.head(3)


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

### Is this correct? Some timepoints are not 45. I don't think I needed to merge because
### I filtered from the original df and kept each record's column data.

# %%
# Put treatments into a list for for loop (and later for plot labels)
### This doesn't even make sense. What are the treatments?


# Create empty list to fill with tumor vol data (for plotting)

tumor_list = filter_tumor_max_df["Tumor Volume (mm3)"].tolist()

tumor_list.sort()

fig1, ax1 = plt.subplots()
ax1.set_title('Drug Regimen')
ax1.set_ylabel('Tumor Volume')
ax1.boxplot(tumor_list)
plt.show()

quartiles = tumor_list.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of temperatures is: {lowerq}")
print(f"The upper quartile of temperatures is: {upperq}")
print(f"The interquartile range of temperatures is: {iqr}")
print(f"The the median of temperatures is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
filter_tumor_max_df

plt.plot(filter_tumor_max_df['Timepoint'], filter_tumor_max_df.Age_months)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-7e12172e7667> in <module>
#       1 # Generate a box plot of the final tumor volume of each mouse across four regimens of interest
# ----> 2 filter_tumor_max_df
#       3
#       4 plt.plot(filter_tumor_max_df['Timepoint'], filter_tumor_max_df.Age_months)
#
# NameError: name 'filter_tumor_max_df' is not defined

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

filter_tumor_max_df

#plt.plot(filter_tumor_max_df.Timepoint, filter_tumor_max_df['Mouse ID']['f966'])
#plt.plot(filter_tumor_max_df['Tumor Volume (mm3)'], filter_tumor_max_df['Mouse ID']['f966'] )

plt.hist(combined_data_df['Tumor Volume (mm3)'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-b30a7c3a4a30> in <module>
#       1 # Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
#       2
# ----> 3 filter_tumor_max_df
#       4
#       5 #plt.plot(filter_tumor_max_df.Timepoint, filter_tumor_max_df['Mouse ID']['f966'])
#
# NameError: name 'filter_tumor_max_df' is not defined

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
